# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
employee_master = pd.read_csv("data/employee_master.csv")
employee_experience = pd.read_csv("data/employee_experience.csv")
client_projects = pd.read_csv("data/client_projects.csv")

# %%
employee_master.head()
# Out:
#   Employee_ID                 Name         Department  Years_Experience  \
# 0        E101        Linda Johnson             DevOps              10.7
# 1        E102  Michael Stevens DDS     Full Stack Dev              11.7
# 2        E103             Cody Lee  Cloud Engineering              10.3
# 3        E104          Tammy Downs        AI Research              10.9
# 4        E105       Richard Wilson  Cloud Engineering               7.4
#
#    Current_Project_ID Location  \
# 0                 NaN    Delhi
# 1                 NaN  Chennai
# 2                 NaN   Mumbai
# 3                 NaN   Mumbai
# 4                 NaN  Chennai
#
#                                               Skills
# 0  AWS, Real-time Data Processing, Serverless Arc...
# 1     Data Governance, Scrum Methodology, Blockchain
# 2  Data Quality Management, Big Data, Data Govern...
# 3           NoSQL Database Management, .Net, GraphQL
# 4  Data Mesh Architecture, Robotic Process Automa...

# %%
employee_experience.head()
# Out:
#   Employee_ID                                    Experience_Text
# 0        E101  Worked on projects involving Microservices, Qu...
# 1        E102  Worked on projects involving Data Privacy Comp...
# 2        E103  Worked on projects involving Scrum, Data Wareh...
# 3        E104  Worked on projects involving CI/CD, Edge Compu...
# 4        E105  Worked on projects involving Penetration Testi...

# %%
employee_master.head()
# Out:
#   Employee_ID                 Name         Department  Years_Experience  \
# 0        E101        Linda Johnson             DevOps              10.7
# 1        E102  Michael Stevens DDS     Full Stack Dev              11.7
# 2        E103             Cody Lee  Cloud Engineering              10.3
# 3        E104          Tammy Downs        AI Research              10.9
# 4        E105       Richard Wilson  Cloud Engineering               7.4
#
#    Current_Project_ID Location  \
# 0                 NaN    Delhi
# 1                 NaN  Chennai
# 2                 NaN   Mumbai
# 3                 NaN   Mumbai
# 4                 NaN  Chennai
#
#                                               Skills
# 0  AWS, Real-time Data Processing, Serverless Arc...
# 1     Data Governance, Scrum Methodology, Blockchain
# 2  Data Quality Management, Big Data, Data Govern...
# 3           NoSQL Database Management, .Net, GraphQL
# 4  Data Mesh Architecture, Robotic Process Automa...

# %%
employees = pd.merge(employee_master, employee_experience, on="Employee_ID", how="left")

employees.head()
# Out:
#   Employee_ID                 Name         Department  Years_Experience  \
# 0        E101        Linda Johnson             DevOps              10.7
# 1        E102  Michael Stevens DDS     Full Stack Dev              11.7
# 2        E103             Cody Lee  Cloud Engineering              10.3
# 3        E104          Tammy Downs        AI Research              10.9
# 4        E105       Richard Wilson  Cloud Engineering               7.4
#
#    Current_Project_ID Location  \
# 0                 NaN    Delhi
# 1                 NaN  Chennai
# 2                 NaN   Mumbai
# 3                 NaN   Mumbai
# 4                 NaN  Chennai
#
#                                               Skills  \
# 0  AWS, Real-time Data Processing, Serverless Arc...
# 1     Data Governance, Scrum Methodology, Blockchain
# 2  Data Quality Management, Big Data, Data Govern...
# 3           NoSQL Database Management, .Net, GraphQL
# 4  Data Mesh Architecture, Robotic Process Automa...
#
#                                      Experience_Text
# 0  Worked on projects involving Microservices, Qu...
# 1  Worked on projects involving Data Privacy Comp...
# 2  Worked on projects involving Scrum, Data Wareh...
# 3  Worked on projects involving CI/CD, Edge Compu...
# 4  Worked on projects involving Penetration Testi...

# %%
def preprocess_text(text):
    if pd.isna(text):
        return ""
    return str(text).lower().replace(",", " ")

# %%
employees["profile_text"] = (
    employees["Department"].fillna("") + " " +
    employees["Skills"].fillna("") + " " +
    employees["Experience_Text"].fillna("") + " " +
    employees["Years_Experience"].astype(str)
).apply(preprocess_text)

client_projects["project_text"] = (
    client_projects["Project_Description"].fillna("") + " " +
    client_projects["Required_Skills"].fillna("")
).apply(preprocess_text)

# %%
employees.head()
# Out:
#   Employee_ID                 Name         Department  Years_Experience  \
# 0        E101        Linda Johnson             DevOps              10.7
# 1        E102  Michael Stevens DDS     Full Stack Dev              11.7
# 2        E103             Cody Lee  Cloud Engineering              10.3
# 3        E104          Tammy Downs        AI Research              10.9
# 4        E105       Richard Wilson  Cloud Engineering               7.4
#
#    Current_Project_ID Location  \
# 0                 NaN    Delhi
# 1                 NaN  Chennai
# 2                 NaN   Mumbai
# 3                 NaN   Mumbai
# 4                 NaN  Chennai
#
#                                               Skills  \
# 0  AWS, Real-time Data Processing, Serverless Arc...
# 1     Data Governance, Scrum Methodology, Blockchain
# 2  Data Quality Management, Big Data, Data Govern...
# 3           NoSQL Database Management, .Net, GraphQL
# 4  Data Mesh Architecture, Robotic Process Automa...
#
#                                      Experience_Text  \
# 0  Worked on projects involving Microservices, Qu...
# 1  Worked on projects involving Data Privacy Comp...
# 2  Worked on projects involving Scrum, Data Wareh...
# 3  Worked on projects involving CI/CD, Edge Compu...
# 4  Worked on projects involving Penetration Testi...
#
#                                         profile_text
# 0  devops aws  real-time data processing  serverl...
# 1  full stack dev data governance  scrum methodol...
# 2  cloud engineering data quality management  big...
# 3  ai research nosql database management  .net  g...
# 4  cloud engineering data mesh architecture  robo...

# %%
vectorizer = TfidfVectorizer(stop_words="english", ngram_range=(1, 2))
tfidf_matrix = vectorizer.fit_transform(
    employees["profile_text"].tolist() + client_projects["project_text"].tolist()
)

employee_tfidf = tfidf_matrix[:len(employees)]
project_tfidf = tfidf_matrix[len(employees):]

# %%
similarity_matrix = cosine_similarity(project_tfidf, employee_tfidf)

# %%
def compute_weighted_score(skill_score, emp_row, project_row,
                           w_skill=0.7, w_exp=0.2, w_location=0.1):
    # Base Skill Similarity (cosine similarity)
    score = skill_score * w_skill

    # Years of Experience (normalize on a scale of 0–1)
    exp_score = min(float(emp_row["Years_Experience"]) / 15.0, 1.0)
    score += exp_score * w_exp

    # Location Match (1 if same, else 0)
    loc_score = 1.0 if emp_row["Location"].lower() == project_row["Location"].lower() else 0.0
    score += loc_score * w_location

    return round(score, 3)

# %%
top_n = 3
recommendations = {}

for proj_idx, project in client_projects.iterrows():
    sims = list(enumerate(similarity_matrix[proj_idx]))
    ranked = []
    for emp_idx, skill_score in sims:
        emp_row = employees.iloc[emp_idx]
        weighted_score = compute_weighted_score(skill_score, emp_row, project)
        ranked.append((emp_idx, weighted_score))

    # Sort employees by final weighted score
    ranked_sorted = sorted(ranked, key=lambda x: x[1], reverse=True)[:top_n]

    recommended_employees = []
    for emp_idx, score in ranked_sorted:
        emp_row = employees.iloc[emp_idx]
        recommended_employees.append({
            "employee_id": emp_row["Employee_ID"],
            "employee_name": emp_row["Name"],
            "department": emp_row["Department"],
            "skills": emp_row["Skills"],
            "location": emp_row["Location"],
            "final_score": score
        })

    recommendations[project["Project_ID"]] = {
        "project_name": project["Client_Name"],
        "required_skills": project["Required_Skills"],
        "recommended_employees": recommended_employees
    }

# %%
for proj_id, rec in recommendations.items():
    print(f"\nProject ID: {proj_id} | Client: {rec['project_name']}")
    print(f"Required Skills: {rec['required_skills']}")
    print("Recommended Employees:")
    for emp in rec["recommended_employees"]:
        print(f"  - {emp['employee_name']} ({emp['department']}, {emp['location']}) "
              f"| Skills: {emp['skills']} --> Final Score: {emp['final_score']}")
# Out:
# Project ID: P301 | Client: Alvarado, Anderson and Brown
# Required Skills: Data Privacy Compliance, AWS, NLP
# Recommended Employees:
#   - William Smith (AI Research, Chennai) | Skills: Data Privacy Compliance, AWS, Data Warehousing --> Final Score: 0.446
#   - Shawn Jones (Cybersecurity, Delhi) | Skills: Data Privacy Compliance, Cloud Security, Docker --> Final Score: 0.38
#   - Megan Davis (Cybersecurity, Delhi) | Skills: Microservices, Data Privacy Compliance, Quantum Computing --> Final Score: 0.373
#
# Project ID: P302 | Client: Cruz-Stokes
# Required Skills: Microservices Architecture, Data Engineering, CI/CD Pipelines
# Recommended Employees:
#   - Brian Terry (Cybersecurity, Chennai) | Skills: Data Mesh Architecture, Data Quality Management, CI/CD Pipelines --> Final Score: 0.442
#   - Scott Adams (Cloud Engineering, Chennai) | Skills: CI/CD, Data Engineering, Data Warehousing --> Final Score: 0.439
#   - Eugene Hayes (Cloud Engineering, Mumbai) | Skills: CI/CD Pipelines, AWS, Data Engineering --> Final Score: 0.424
#
# Project ID: P303 | Client: Petersen, Bryant and Jackson
# Required Skills: GraphQL, Edge Computing, Robotic Process Automation
# Recommended Employees:
#   - Sarah Simmons (AI Research, Delhi) | Skills: SQL Database Management, REST APIs, Real-time Data Processing --> Final Score: 0.45
#   - Raymond Mendoza (Cloud Engineering, Delhi) | Skills: Data Engineering, Kubernetes, Robotic Process Automation --> Final Score: 0.438
#   - Regina Zimmerman (Full Stack Dev, Delhi) | Skills: Node.js, React, Robotic Process Automation --> Final Score: 0.434
#
# Project ID: P304 | Client: Lawson Ltd
# Required Skills: Data Engineering, Agile Project Management, Business Intelligence
# Recommended Employees:
#   - Julie White (Cybersecurity, Delhi) | Skills: Data Engineering, Agile Project Management, Business Intelligence --> Final Score: 0.593
#   - Cynthia Mckee (DevOps, Delhi) | Skills: Quantum Computing, UI/UX Design, Data Visualization --> Final Score: 0.435
#   - Jeffery Horn (Full Stack Dev, Delhi) | Skills: Quantum Computing, Container Orchestration, IoT --> Final Score: 0.39
#
# Project ID: P305 | Client: Davis, Anderson and Brown
# Required Skills: Jenkins, Blockchain, Scrum Methodology
# Recommended Employees:
#   - Billy Johnson (Cybersecurity, Delhi) | Skills: Data Governance, Serverless Architecture, Network Security --> Final Score: 0.379
#   - Paul Jones (Cybersecurity, Delhi) | Skills: Jenkins, Scrum Methodology, IoT --> Final Score: 0.35
#   - Christopher Castillo (AI Research, Delhi) | Skills: Data Engineering, Cloud Security, Node.js --> Final Score: 0.347
#
# Project ID: P306 | Client: Stephens-Knight
# Required Skills: Terraform, NoSQL Database Management, SQL
# Recommended Employees:
#   - Danielle Maldonado (AI Research, Delhi) | Skills: Agile Project Management, NLP, NoSQL Database Management --> Final Score: 0.446
#   - Harry Moore (Cloud Engineering, Pune) | Skills: Business Intelligence, Data Engineering, SQL --> Final Score: 0.444
#   - Jason Banks (AI Research, Pune) | Skills: Machine Learning, React, Python --> Final Score: 0.424
#
# Project ID: P307 | Client: Hester-Walter
# Required Skills: Kubernetes, Network Security, Data Visualization
# Recommended Employees:
#   - Lorraine Baker (Cybersecurity, Mumbai) | Skills: Cloud Security, Data Governance, Data Visualization --> Final Score: 0.475
#   - Cheryl Parsons (Data Science, Mumbai) | Skills: Container Orchestration, Big Data, SQL --> Final Score: 0.453
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.412
#
# Project ID: P308 | Client: Keith-White
# Required Skills: Edge Computing, CI/CD, Docker
# Recommended Employees:
#   - Dr. Michelle Barnes (Cloud Engineering, Mumbai) | Skills: CI/CD, Healthcare Analytics, Edge Computing --> Final Score: 0.411
#   - Thomas Rivas (AI Research, Mumbai) | Skills: CI/CD, Cloud Security, Edge Computing --> Final Score: 0.398
#   - Amanda Livingston (DevOps, Mumbai) | Skills: Data Quality Management, CI/CD Pipelines, Edge Computing --> Final Score: 0.393
#
# Project ID: P309 | Client: Ewing, Price and Santiago
# Required Skills: API Development, Kubernetes, Agile
# Recommended Employees:
#   - Angela Norris (DevOps, Mumbai) | Skills: Mobile Development, Kubernetes, Docker --> Final Score: 0.381
#   - Nathaniel Fisher (Cloud Engineering, Mumbai) | Skills: Data Lake Implementation, GraphQL API Development, API Development --> Final Score: 0.359
#   - Robert Mitchell DVM (Cybersecurity, Mumbai) | Skills: API Development, NoSQL Database Management, Jenkins --> Final Score: 0.356
#
# Project ID: P310 | Client: Wright and Sons
# Required Skills: Business Intelligence, Data Mesh Architecture, Serverless Architecture
# Recommended Employees:
#   - Jacob Wall (Full Stack Dev, Chennai) | Skills: Business Intelligence, PostgreSQL, Data Mesh Architecture --> Final Score: 0.425
#   - Alexander Hart (DevOps, Chennai) | Skills: IoT, .Net, Healthcare Analytics --> Final Score: 0.424
#   - Jacob Rush (Full Stack Dev, Chennai) | Skills: Business Intelligence, Scrum, Data Quality Management --> Final Score: 0.415
#
# Project ID: P311 | Client: Hicks-Henderson
# Required Skills: Node.js, Cybersecurity, CI/CD
# Recommended Employees:
#   - Justin Butler (DevOps, Delhi) | Skills: Docker, CI/CD Pipelines, Edge Computing --> Final Score: 0.377
#   - Shelly Fields (Full Stack Dev, Delhi) | Skills: Real-time Data Processing, Serverless Architecture, NoSQL --> Final Score: 0.375
#   - Alexandra David (Full Stack Dev, Delhi) | Skills: Docker, CI/CD, Healthcare Analytics --> Final Score: 0.375
#
# Project ID: P312 | Client: Wagner, Fisher and Hart
# Required Skills: Data Engineering, Network Security, PostgreSQL
# Recommended Employees:
#   - Robert Obrien Jr. (Cybersecurity, Chennai) | Skills: Agile, Scrum Methodology, Cloud Security --> Final Score: 0.405
#   - Jill Cox (Data Science, Chennai) | Skills: Quantum Computing, PostgreSQL, Data Mesh Architecture --> Final Score: 0.396
#   - Scott Adams (Cloud Engineering, Chennai) | Skills: CI/CD, Data Engineering, Data Warehousing --> Final Score: 0.39
#
# Project ID: P313 | Client: Wagner, Meyers and Lee
# Required Skills: Data Lake Implementation, Data Quality Management, REST APIs
# Recommended Employees:
#   - Dr. Brenda Allen DDS (Full Stack Dev, Pune) | Skills: Node.js, IoT, Data Lake Implementation --> Final Score: 0.413
#   - Jamie Spencer (Full Stack Dev, Pune) | Skills: Healthcare Analytics, NoSQL Database Management, REST APIs --> Final Score: 0.407
#   - Gabriela Cohen (Data Science, Pune) | Skills: Data Lake Implementation, Data Governance, Mobile Development --> Final Score: 0.406
#
# Project ID: P314 | Client: Hughes-Coleman
# Required Skills: Blockchain, Machine Learning, AWS
# Recommended Employees:
#   - Christopher Allen (Data Science, Pune) | Skills: CI/CD, Data Quality Management, Machine Learning --> Final Score: 0.376
#   - Joel Hamilton (Cybersecurity, Pune) | Skills: Quantum Computing, Incident Response, Business Intelligence --> Final Score: 0.361
#   - Jason Banks (AI Research, Pune) | Skills: Machine Learning, React, Python --> Final Score: 0.353
#
# Project ID: P315 | Client: Henderson Inc
# Required Skills: Incident Response, Mobile Development, Quantum Computing
# Recommended Employees:
#   - Toni Gonzalez (Full Stack Dev, Pune) | Skills: Terraform, IoT, Quantum Computing --> Final Score: 0.412
#   - Joel Hamilton (Cybersecurity, Pune) | Skills: Quantum Computing, Incident Response, Business Intelligence --> Final Score: 0.411
#   - Aaron Wheeler (Cloud Engineering, Pune) | Skills: Incident Response, TensorFlow, Mobile Development --> Final Score: 0.402
#
# Project ID: P316 | Client: Kelly-Hayes
# Required Skills: Machine Learning, Cloud Security, Healthcare Analytics
# Recommended Employees:
#   - Carlos Rosales (Cloud Engineering, Pune) | Skills: Java, Machine Learning, Cloud Security --> Final Score: 0.472
#   - Joel Hamilton (Cybersecurity, Pune) | Skills: Quantum Computing, Incident Response, Business Intelligence --> Final Score: 0.386
#   - Christopher Allen (Data Science, Pune) | Skills: CI/CD, Data Quality Management, Machine Learning --> Final Score: 0.379
#
# Project ID: P317 | Client: Reynolds LLC
# Required Skills: DevOps Practices, Terraform, Edge Computing
# Recommended Employees:
#   - Maurice Tucker (AI Research, Pune) | Skills: Edge Computing, DevOps Practices, Penetration Testing --> Final Score: 0.442
#   - Chelsea Williams DVM (Cybersecurity, Pune) | Skills: Data Engineering, Edge Computing, Big Data --> Final Score: 0.398
#   - Kristen Pratt (Data Science, Chennai) | Skills: SQL Database Management, Quantum Computing, GraphQL --> Final Score: 0.396
#
# Project ID: P318 | Client: Davis-Peterson
# Required Skills: Penetration Testing, Data Mesh Architecture, UI/UX Design
# Recommended Employees:
#   - Stacy Alexander (Full Stack Dev, Mumbai) | Skills: Container Orchestration, NLP, Microservices --> Final Score: 0.466
#   - Isaac Johnson (DevOps, Mumbai) | Skills: Scrum Methodology, UI/UX Design, Python --> Final Score: 0.46
#   - Aaron Clark (Full Stack Dev, Mumbai) | Skills: Scrum, NoSQL, Network Security --> Final Score: 0.457
#
# Project ID: P319 | Client: Rhodes-Miller
# Required Skills: Data Engineering, Business Intelligence, GraphQL API Development
# Recommended Employees:
#   - Jacob Rush (Full Stack Dev, Chennai) | Skills: Business Intelligence, Scrum, Data Quality Management --> Final Score: 0.478
#   - Karen Ayala (Cybersecurity, Chennai) | Skills: React, Cloud Security, Edge Computing --> Final Score: 0.42
#   - Mr. Ryan Watson (Cybersecurity, Chennai) | Skills: Incident Response, Blockchain, NoSQL --> Final Score: 0.393
#
# Project ID: P320 | Client: Stout Group
# Required Skills: Data Visualization, Serverless Architecture, Data Privacy Compliance
# Recommended Employees:
#   - Anthony Watkins (Data Science, Chennai) | Skills: NoSQL, Data Visualization, Penetration Testing --> Final Score: 0.475
#   - William Smith (AI Research, Chennai) | Skills: Data Privacy Compliance, AWS, Data Warehousing --> Final Score: 0.444
#   - James Lewis (Full Stack Dev, Chennai) | Skills: Serverless Architecture, Data Lake Implementation, PostgreSQL --> Final Score: 0.436
#
# Project ID: P321 | Client: Gonzalez Group
# Required Skills: IoT, Python, Data Warehousing
# Recommended Employees:
#   - Zachary Hughes (Data Science, Pune) | Skills: DevOps Practices, Python, Data Mesh Architecture --> Final Score: 0.381
#   - Tyler Dominguez (Data Science, Pune) | Skills: Data Mesh Architecture, Data Warehousing, AWS --> Final Score: 0.378
#   - Grace Barrett (AI Research, Pune) | Skills: Python, API Development, Data Mesh Architecture --> Final Score: 0.375
#
# Project ID: P322 | Client: Evans PLC
# Required Skills: Data Lake Implementation, Machine Learning, NoSQL
# Recommended Employees:
#   - Christine Hall (Data Science, Chennai) | Skills: Microservices, NLP, Data Lake Implementation --> Final Score: 0.492
#   - Gabriel Chavez (Full Stack Dev, Chennai) | Skills: .Net, NoSQL Database Management, Mobile Development --> Final Score: 0.437
#   - Kim Ramirez (Cloud Engineering, Chennai) | Skills: Machine Learning, Blockchain, DevOps Practices --> Final Score: 0.405
#
# Project ID: P323 | Client: Rosario, Castro and Romero
# Required Skills: NoSQL Database Management, Agile Project Management, Scrum Methodology
# Recommended Employees:
#   - Leslie Petty (Data Science, Chennai) | Skills: UI/UX Design, NoSQL Database Management, CI/CD Pipelines --> Final Score: 0.49
#   - Angela Mcguire (Full Stack Dev, Chennai) | Skills: Agile, NoSQL Database Management, Agile Project Management --> Final Score: 0.46
#   - Jack Cruz (Cybersecurity, Chennai) | Skills: Quantum Computing, Big Data, Real-time Data Processing --> Final Score: 0.432
#
# Project ID: P324 | Client: Edwards Group
# Required Skills: Microservices, Real-time Data Processing, React
# Recommended Employees:
#   - Kevin Hernandez (Cloud Engineering, Pune) | Skills: Microservices, Real-time Data Processing, TensorFlow --> Final Score: 0.509
#   - Maurice Tucker (AI Research, Pune) | Skills: Edge Computing, DevOps Practices, Penetration Testing --> Final Score: 0.496
#   - Joshua Hartman (DevOps, Pune) | Skills: PostgreSQL, UI/UX Design, Data Warehousing --> Final Score: 0.443
#
# Project ID: P325 | Client: Stephens Inc
# Required Skills: Robotic Process Automation, UI/UX Design, Cybersecurity
# Recommended Employees:
#   - Casey Graham (Cybersecurity, Pune) | Skills: Python, SQL, Cybersecurity --> Final Score: 0.411
#   - Rebecca Blair (Cybersecurity, Pune) | Skills: API Development, Data Visualization, Blockchain --> Final Score: 0.405
#   - James Stanley (Cloud Engineering, Pune) | Skills: PostgreSQL, NoSQL, Data Warehousing --> Final Score: 0.398
#
# Project ID: P326 | Client: Reese Ltd
# Required Skills: TensorFlow, Scrum Methodology, Agile
# Recommended Employees:
#   - Robert Obrien Jr. (Cybersecurity, Chennai) | Skills: Agile, Scrum Methodology, Cloud Security --> Final Score: 0.406
#   - Robin Johnson (Cloud Engineering, Chennai) | Skills: UI/UX Design, PostgreSQL, Scrum Methodology --> Final Score: 0.378
#   - Carrie Evans (DevOps, Chennai) | Skills: Scrum Methodology, Cloud Security, DevOps Practices --> Final Score: 0.362
#
# Project ID: P327 | Client: Bennett and Sons
# Required Skills: TensorFlow, NoSQL, Data Governance
# Recommended Employees:
#   - Kelly Richards (Full Stack Dev, Chennai) | Skills: TensorFlow, PostgreSQL, Data Governance --> Final Score: 0.366
#   - Anthony Watson (Data Science, Chennai) | Skills: Healthcare Analytics, Data Governance, UI/UX Design --> Final Score: 0.356
#   - Anna Snyder (Full Stack Dev, Chennai) | Skills: Edge Computing, React, API Development --> Final Score: 0.351
#
# Project ID: P328 | Client: Turner, Barrett and Hanson
# Required Skills: NLP, Container Orchestration, IoT
# Recommended Employees:
#   - Jeffery Horn (Full Stack Dev, Delhi) | Skills: Quantum Computing, Container Orchestration, IoT --> Final Score: 0.372
#   - Tracey Reyes (Data Science, Mumbai) | Skills: Data Visualization, SQL, Penetration Testing --> Final Score: 0.367
#   - Samantha Moon (Cloud Engineering, Mumbai) | Skills: DevOps Practices, AWS, Container Orchestration --> Final Score: 0.367
#
# Project ID: P329 | Client: Yates PLC
# Required Skills: React, Jenkins, Data Lake Implementation
# Recommended Employees:
#   - Karen Reynolds (Full Stack Dev, Delhi) | Skills: Node.js, Terraform, Incident Response --> Final Score: 0.404
#   - Karen Edwards (Data Science, Delhi) | Skills: Jenkins, Data Lake Implementation, .Net --> Final Score: 0.397
#   - Jamie Williamson (Full Stack Dev, Delhi) | Skills: Data Mesh Architecture, GraphQL API Development, Data Lake Implementation --> Final Score: 0.394
#
# Project ID: P330 | Client: Hall, Duran and Rocha
# Required Skills: Data Governance, Quantum Computing, Cybersecurity
# Recommended Employees:
#   - Angel Norris (DevOps, Pune) | Skills: Quantum Computing, Cybersecurity, Data Governance --> Final Score: 0.474
#   - Melissa Lam (DevOps, Pune) | Skills: Business Intelligence, Terraform, Scrum Methodology --> Final Score: 0.429
#   - Paul Jackson (Full Stack Dev, Pune) | Skills: Data Visualization, Quantum Computing, Agile Project Management --> Final Score: 0.413
#
# Project ID: P331 | Client: Collins PLC
# Required Skills: React, Network Security, Data Warehousing
# Recommended Employees:
#   - Lorraine Baker (Cybersecurity, Mumbai) | Skills: Cloud Security, Data Governance, Data Visualization --> Final Score: 0.463
#   - Cheryl Parsons (Data Science, Mumbai) | Skills: Container Orchestration, Big Data, SQL --> Final Score: 0.425
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.413
#
# Project ID: P332 | Client: Martin-Martin
# Required Skills: NLP, Cybersecurity, Healthcare Analytics
# Recommended Employees:
#   - Ashley Johnson (Cybersecurity, Pune) | Skills: Healthcare Analytics, PostgreSQL, Azure --> Final Score: 0.443
#   - Teresa Allen (Data Science, Pune) | Skills: Cybersecurity, Java, Data Privacy Compliance --> Final Score: 0.367
#   - Andrew Murray (DevOps, Pune) | Skills: Scrum, Penetration Testing, React --> Final Score: 0.36
#
# Project ID: P333 | Client: Rivera, Edwards and Carter
# Required Skills: Node.js, GraphQL API Development, NoSQL
# Recommended Employees:
#   - Erin Flores (Cloud Engineering, Pune) | Skills: Data Lake Implementation, GraphQL API Development, NoSQL Database Management --> Final Score: 0.431
#   - Amanda Harrell (AI Research, Pune) | Skills: GraphQL API Development, NoSQL Database Management, Data Governance --> Final Score: 0.418
#   - Richard Johnson (AI Research, Chennai) | Skills: React, Incident Response, TensorFlow --> Final Score: 0.417
#
# Project ID: P334 | Client: Martinez, Holden and Manning
# Required Skills: Data Governance, PostgreSQL, Azure
# Recommended Employees:
#   - Kelly Richards (Full Stack Dev, Chennai) | Skills: TensorFlow, PostgreSQL, Data Governance --> Final Score: 0.402
#   - Anna Snyder (Full Stack Dev, Chennai) | Skills: Edge Computing, React, API Development --> Final Score: 0.388
#   - Brian Burnett (AI Research, Chennai) | Skills: Business Intelligence, Agile Project Management, NoSQL --> Final Score: 0.356
#
# Project ID: P335 | Client: Warren-Robertson
# Required Skills: NoSQL, Serverless Architecture, Kubernetes
# Recommended Employees:
#   - Shirley Johnson (Cybersecurity, Delhi) | Skills: Incident Response, PostgreSQL, NoSQL --> Final Score: 0.395
#   - Courtney Rodriguez (Data Science, Delhi) | Skills: Incident Response, .Net, Scrum Methodology --> Final Score: 0.391
#   - Shelly Fields (Full Stack Dev, Delhi) | Skills: Real-time Data Processing, Serverless Architecture, NoSQL --> Final Score: 0.373
#
# Project ID: P336 | Client: Dunn, Braun and Coleman
# Required Skills: Scrum, Data Governance, Data Warehousing
# Recommended Employees:
#   - Paul Jackson (Full Stack Dev, Pune) | Skills: Data Visualization, Quantum Computing, Agile Project Management --> Final Score: 0.377
#   - Morgan Ewing (Full Stack Dev, Delhi) | Skills: Incident Response, Network Security, Data Governance --> Final Score: 0.374
#   - Cynthia Hammond (AI Research, Delhi) | Skills: Business Intelligence, Big Data, Data Quality Management --> Final Score: 0.365
#
# Project ID: P337 | Client: Diaz Group
# Required Skills: NoSQL Database Management, Robotic Process Automation, UI/UX Design
# Recommended Employees:
#   - David Smith (Full Stack Dev, Chennai) | Skills: Scrum, NoSQL Database Management, Data Mesh Architecture --> Final Score: 0.538
#   - Kelly Richards (Full Stack Dev, Chennai) | Skills: TensorFlow, PostgreSQL, Data Governance --> Final Score: 0.465
#   - Joshua Gates (AI Research, Chennai) | Skills: Blockchain, Quantum Computing, Robotic Process Automation --> Final Score: 0.457
#
# Project ID: P338 | Client: Morrow Inc
# Required Skills: REST APIs, GraphQL API Development, Mobile Development
# Recommended Employees:
#   - Jesse Clark (Cybersecurity, Chennai) | Skills: Scrum Methodology, SQL, Agile Project Management --> Final Score: 0.465
#   - Joshua Gates (AI Research, Chennai) | Skills: Blockchain, Quantum Computing, Robotic Process Automation --> Final Score: 0.459
#   - Nathan Whitehead (AI Research, Chennai) | Skills: IoT, Data Visualization, GraphQL API Development --> Final Score: 0.408
#
# Project ID: P339 | Client: Banks Inc
# Required Skills: Business Intelligence, Data Warehousing, Cloud Security
# Recommended Employees:
#   - Stephanie Cunningham DDS (Cloud Engineering, Mumbai) | Skills: GraphQL, CI/CD, Real-time Data Processing --> Final Score: 0.404
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.397
#   - Cindy Levy (DevOps, Mumbai) | Skills: Real-time Data Processing, Agile Project Management, Microservices --> Final Score: 0.397
#
# Project ID: P340 | Client: Reese, Gilbert and Simmons
# Required Skills: Java, Python, Big Data
# Recommended Employees:
#   - Erin Cooper (DevOps, Chennai) | Skills: Data Lake Implementation, Big Data, Serverless Architecture --> Final Score: 0.41
#   - Joseph Nash (Cybersecurity, Chennai) | Skills: Java, Python, Data Quality Management --> Final Score: 0.406
#   - Christine Hall (Data Science, Chennai) | Skills: Microservices, NLP, Data Lake Implementation --> Final Score: 0.382
#
# Project ID: P341 | Client: Cortez and Sons
# Required Skills: Cybersecurity, TensorFlow, Docker
# Recommended Employees:
#   - Whitney Reyes (Cybersecurity, Pune) | Skills: TensorFlow, Jenkins, Docker --> Final Score: 0.37
#   - David Gutierrez (Cybersecurity, Pune) | Skills: Cybersecurity, TensorFlow, Robotic Process Automation --> Final Score: 0.368
#   - Ronald Kelley (Cloud Engineering, Pune) | Skills: Business Intelligence, Docker, UI/UX Design --> Final Score: 0.341
#
# Project ID: P342 | Client: Marsh PLC
# Required Skills: Mobile Development, Business Intelligence, Container Orchestration
# Recommended Employees:
#   - Mr. Ryan Watson (Cybersecurity, Chennai) | Skills: Incident Response, Blockchain, NoSQL --> Final Score: 0.44
#   - Karen Ayala (Cybersecurity, Chennai) | Skills: React, Cloud Security, Edge Computing --> Final Score: 0.433
#   - Hailey Williams (Data Science, Chennai) | Skills: API Development, Business Intelligence, REST APIs --> Final Score: 0.401
#
# Project ID: P343 | Client: Greene-Thompson
# Required Skills: GraphQL API Development, Scrum, Container Orchestration
# Recommended Employees:
#   - Zachary Hill (Cybersecurity, Pune) | Skills: Business Intelligence, Container Orchestration, Docker --> Final Score: 0.438
#   - Brandon Jimenez (Cloud Engineering, Pune) | Skills: Serverless Architecture, Docker, GraphQL API Development --> Final Score: 0.416
#   - Samantha Fuller (Full Stack Dev, Pune) | Skills: Serverless Architecture, Blockchain, GraphQL API Development --> Final Score: 0.395
#
# Project ID: P344 | Client: Lozano and Sons
# Required Skills: Blockchain, Penetration Testing, GraphQL
# Recommended Employees:
#   - Steven Jensen (Full Stack Dev, Mumbai) | Skills: Container Orchestration, NLP, Penetration Testing --> Final Score: 0.415
#   - Joseph Duran (Cybersecurity, Mumbai) | Skills: UI/UX Design, Penetration Testing, GraphQL --> Final Score: 0.388
#   - Erin Flores (Cloud Engineering, Pune) | Skills: Data Lake Implementation, GraphQL API Development, NoSQL Database Management --> Final Score: 0.373
#
# Project ID: P345 | Client: Ayala-Dean
# Required Skills: Data Quality Management, Network Security, Azure
# Recommended Employees:
#   - Cheryl Parsons (Data Science, Mumbai) | Skills: Container Orchestration, Big Data, SQL --> Final Score: 0.439
#   - Kelsey Gomez (DevOps, Mumbai) | Skills: NoSQL Database Management, Network Security, SQL --> Final Score: 0.438
#   - Monica Farrell (Cloud Engineering, Mumbai) | Skills: Network Security, Azure, Data Privacy Compliance --> Final Score: 0.426
#
# Project ID: P346 | Client: Gardner, Murphy and Anderson
# Required Skills: Penetration Testing, Data Privacy Compliance, Data Governance
# Recommended Employees:
#   - Morgan Ewing (Full Stack Dev, Delhi) | Skills: Incident Response, Network Security, Data Governance --> Final Score: 0.428
#   - Eric Rollins (DevOps, Delhi) | Skills: CI/CD Pipelines, Java, NLP --> Final Score: 0.404
#   - Michael Diaz (DevOps, Delhi) | Skills: Data Privacy Compliance, Data Visualization, SQL Database Management --> Final Score: 0.386
#
# Project ID: P347 | Client: Stephens-White
# Required Skills: Azure, Data Lake Implementation, Agile Project Management
# Recommended Employees:
#   - Jerry Lee (DevOps, Chennai) | Skills: NoSQL, Data Lake Implementation, Agile Project Management --> Final Score: 0.428
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.42
#   - Sarah Allen (Full Stack Dev, Mumbai) | Skills: Cybersecurity, Jenkins, PostgreSQL --> Final Score: 0.419
#
# Project ID: P348 | Client: Grant-Lutz
# Required Skills: CI/CD Pipelines, Scrum, Data Governance
# Recommended Employees:
#   - Eugene Hayes (Cloud Engineering, Mumbai) | Skills: CI/CD Pipelines, AWS, Data Engineering --> Final Score: 0.4
#   - John Stewart (DevOps, Mumbai) | Skills: CI/CD Pipelines, Quantum Computing, Scrum --> Final Score: 0.395
#   - Katrina Manning (Full Stack Dev, Mumbai) | Skills: IoT, Data Mesh Architecture, Terraform --> Final Score: 0.395
#
# Project ID: P349 | Client: Sanchez-Young
# Required Skills: DevOps Practices, Robotic Process Automation, API Development
# Recommended Employees:
#   - James Stanley (Cloud Engineering, Pune) | Skills: PostgreSQL, NoSQL, Data Warehousing --> Final Score: 0.445
#   - Rebecca Blair (Cybersecurity, Pune) | Skills: API Development, Data Visualization, Blockchain --> Final Score: 0.439
#   - Brianna Dawson (Data Science, Mumbai) | Skills: Big Data, Robotic Process Automation, Agile Project Management --> Final Score: 0.428
#
# Project ID: P350 | Client: Fisher-Fisher
# Required Skills: Agile, Data Governance, CI/CD
# Recommended Employees:
#   - Alexandra Richards (AI Research, Pune) | Skills: SQL, Agile Project Management, Data Governance --> Final Score: 0.404
#   - Christopher Allen (Data Science, Pune) | Skills: CI/CD, Data Quality Management, Machine Learning --> Final Score: 0.386
#   - Kimberly Lawson (AI Research, Pune) | Skills: Edge Computing, Data Governance, CI/CD Pipelines --> Final Score: 0.379
#
# Project ID: P351 | Client: Sloan and Sons
# Required Skills: UI/UX Design, Blockchain, Data Engineering
# Recommended Employees:
#   - Deanna Foster (AI Research, Delhi) | Skills: UI/UX Design, Cloud Security, Data Warehousing --> Final Score: 0.458
#   - Andrew Watson (AI Research, Delhi) | Skills: Network Security, Data Engineering, CI/CD Pipelines --> Final Score: 0.405
#   - Cory Gonzalez (DevOps, Delhi) | Skills: Data Visualization, Microservices, GraphQL --> Final Score: 0.405
#
# Project ID: P352 | Client: Jackson Ltd
# Required Skills: Microservices Architecture, Data Governance, Network Security
# Recommended Employees:
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.442
#   - Lorraine Baker (Cybersecurity, Mumbai) | Skills: Cloud Security, Data Governance, Data Visualization --> Final Score: 0.438
#   - Robert Mitchell DVM (Cybersecurity, Mumbai) | Skills: API Development, NoSQL Database Management, Jenkins --> Final Score: 0.434
#
# Project ID: P353 | Client: Castro-Peters
# Required Skills: Java, DevOps Practices, Scrum Methodology
# Recommended Employees:
#   - Carrie Evans (DevOps, Chennai) | Skills: Scrum Methodology, Cloud Security, DevOps Practices --> Final Score: 0.401
#   - Michael Stevens DDS (Full Stack Dev, Chennai) | Skills: Data Governance, Scrum Methodology, Blockchain --> Final Score: 0.374
#   - Barry Collins (AI Research, Chennai) | Skills: DevOps Practices, Azure, Java --> Final Score: 0.372
#
# Project ID: P354 | Client: Evans-Johnson
# Required Skills: Azure, Mobile Development, Cloud Security
# Recommended Employees:
#   - Toni Gonzalez (Full Stack Dev, Pune) | Skills: Terraform, IoT, Quantum Computing --> Final Score: 0.391
#   - Andrew Obrien (Cloud Engineering, Pune) | Skills: Mobile Development, PostgreSQL, UI/UX Design --> Final Score: 0.366
#   - Karen Johnson (DevOps, Pune) | Skills: UI/UX Design, Azure, Incident Response --> Final Score: 0.365
#
# Project ID: P355 | Client: Williams Group
# Required Skills: Mobile Development, Quantum Computing, REST APIs
# Recommended Employees:
#   - Toni Gonzalez (Full Stack Dev, Pune) | Skills: Terraform, IoT, Quantum Computing --> Final Score: 0.415
#   - Aaron Wheeler (Cloud Engineering, Pune) | Skills: Incident Response, TensorFlow, Mobile Development --> Final Score: 0.403
#   - Matthew Williams (AI Research, Pune) | Skills: IoT, Penetration Testing, Quantum Computing --> Final Score: 0.388
#
# Project ID: P356 | Client: Friedman Ltd
# Required Skills: GraphQL API Development, Business Intelligence, Mobile Development
# Recommended Employees:
#   - Breanna Miller (Data Science, Delhi) | Skills: CI/CD, GraphQL API Development, GraphQL --> Final Score: 0.456
#   - Karen Ayala (Cybersecurity, Chennai) | Skills: React, Cloud Security, Edge Computing --> Final Score: 0.412
#   - Mr. Ryan Watson (Cybersecurity, Chennai) | Skills: Incident Response, Blockchain, NoSQL --> Final Score: 0.376
#
# Project ID: P357 | Client: Robinson, Henderson and Bell
# Required Skills: Java, AWS, NLP
# Recommended Employees:
#   - Teresa Allen (Data Science, Pune) | Skills: Cybersecurity, Java, Data Privacy Compliance --> Final Score: 0.348
#   - Elizabeth Morgan (DevOps, Pune) | Skills: REST APIs, Robotic Process Automation, Container Orchestration --> Final Score: 0.339
#   - Heather Shelton (Data Science, Pune) | Skills: Big Data, GraphQL, Data Quality Management --> Final Score: 0.326
#
# Project ID: P358 | Client: Wiley PLC
# Required Skills: Penetration Testing, Agile Project Management, NoSQL
# Recommended Employees:
#   - Mr. Alexis Vasquez (DevOps, Chennai) | Skills: NoSQL Database Management, Data Warehousing, AWS --> Final Score: 0.475
#   - Brian Burnett (AI Research, Chennai) | Skills: Business Intelligence, Agile Project Management, NoSQL --> Final Score: 0.475
#   - Brian Terry (Cybersecurity, Chennai) | Skills: Data Mesh Architecture, Data Quality Management, CI/CD Pipelines --> Final Score: 0.415
#
# Project ID: P359 | Client: Herrera-Casey
# Required Skills: Agile, Data Visualization, NLP
# Recommended Employees:
#   - Jeffrey Jimenez (Cloud Engineering, Chennai) | Skills: Data Visualization, NLP, Agile Project Management --> Final Score: 0.387
#   - Lorraine Baker (Cybersecurity, Mumbai) | Skills: Cloud Security, Data Governance, Data Visualization --> Final Score: 0.363
#   - Cheryl Parsons (Data Science, Mumbai) | Skills: Container Orchestration, Big Data, SQL --> Final Score: 0.359
#
# Project ID: P360 | Client: Strong Group
# Required Skills: Healthcare Analytics, AWS, UI/UX Design
# Recommended Employees:
#   - Isaac Johnson (DevOps, Mumbai) | Skills: Scrum Methodology, UI/UX Design, Python --> Final Score: 0.448
#   - Samantha Moon (Cloud Engineering, Mumbai) | Skills: DevOps Practices, AWS, Container Orchestration --> Final Score: 0.415
#   - Aaron Clark (Full Stack Dev, Mumbai) | Skills: Scrum, NoSQL, Network Security --> Final Score: 0.39
#
# Project ID: P361 | Client: Franklin-Carrillo
# Required Skills: Docker, REST APIs, Microservices Architecture
# Recommended Employees:
#   - Jacob Wall (Full Stack Dev, Chennai) | Skills: Business Intelligence, PostgreSQL, Data Mesh Architecture --> Final Score: 0.364
#   - Bradley Williams (Data Science, Chennai) | Skills: Serverless Architecture, Data Engineering, Scrum Methodology --> Final Score: 0.364
#   - Robert Obrien Jr. (Cybersecurity, Chennai) | Skills: Agile, Scrum Methodology, Cloud Security --> Final Score: 0.364
#
# Project ID: P362 | Client: Thompson Ltd
# Required Skills: Microservices, DevOps Practices, GraphQL
# Recommended Employees:
#   - Amber Navarro (Cloud Engineering, Mumbai) | Skills: DevOps Practices, NoSQL Database Management, Agile Project Management --> Final Score: 0.382
#   - Samantha Moon (Cloud Engineering, Mumbai) | Skills: DevOps Practices, AWS, Container Orchestration --> Final Score: 0.369
#   - Cheryl Parsons (Data Science, Mumbai) | Skills: Container Orchestration, Big Data, SQL --> Final Score: 0.337
#
# Project ID: P363 | Client: Wright LLC
# Required Skills: Terraform, NLP, SQL
# Recommended Employees:
#   - Heather Shelton (Data Science, Pune) | Skills: Big Data, GraphQL, Data Quality Management --> Final Score: 0.351
#   - Cameron Morgan (Data Science, Pune) | Skills: Terraform, NLP, IoT --> Final Score: 0.347
#   - Scott Herrera (DevOps, Pune) | Skills: SQL Database Management, SQL, Business Intelligence --> Final Score: 0.346
#
# Project ID: P364 | Client: Burton, Juarez and Moss
# Required Skills: DevOps Practices, Incident Response, Real-time Data Processing
# Recommended Employees:
#   - Dustin Martinez (Cloud Engineering, Chennai) | Skills: NoSQL, Real-time Data Processing, Cloud Security --> Final Score: 0.551
#   - Blake Rios (Cybersecurity, Chennai) | Skills: Data Warehousing, API Development, Data Privacy Compliance --> Final Score: 0.472
#   - Jack Cruz (Cybersecurity, Chennai) | Skills: Quantum Computing, Big Data, Real-time Data Processing --> Final Score: 0.444
#
# Project ID: P365 | Client: Wallace-Avila
# Required Skills: Data Mesh Architecture, Docker, Data Lake Implementation
# Recommended Employees:
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.436
#   - Christopher Allen (Data Science, Pune) | Skills: CI/CD, Data Quality Management, Machine Learning --> Final Score: 0.399
#   - Grace Barrett (AI Research, Pune) | Skills: Python, API Development, Data Mesh Architecture --> Final Score: 0.396
#
# Project ID: P366 | Client: Gonzalez PLC
# Required Skills: Docker, Business Intelligence, Microservices
# Recommended Employees:
#   - Ronald Kelley (Cloud Engineering, Pune) | Skills: Business Intelligence, Docker, UI/UX Design --> Final Score: 0.398
#   - Jessica Richardson (Cybersecurity, Pune) | Skills: React, Business Intelligence, Microservices --> Final Score: 0.389
#   - Joel Hamilton (Cybersecurity, Pune) | Skills: Quantum Computing, Incident Response, Business Intelligence --> Final Score: 0.362
#
# Project ID: P367 | Client: Nunez-Hodge
# Required Skills: AWS, Docker, Data Privacy Compliance
# Recommended Employees:
#   - Elizabeth Waters DDS (Full Stack Dev, Pune) | Skills: Blockchain, Docker, Big Data --> Final Score: 0.413
#   - Teresa Allen (Data Science, Pune) | Skills: Cybersecurity, Java, Data Privacy Compliance --> Final Score: 0.389
#   - Christopher Perez (AI Research, Pune) | Skills: Scrum Methodology, Cybersecurity, Blockchain --> Final Score: 0.373
#
# Project ID: P368 | Client: Patterson-Hicks
# Required Skills: Azure, Cloud Security, NLP
# Recommended Employees:
#   - Alice Williams (Data Science, Chennai) | Skills: Cloud Security, NLP, Big Data --> Final Score: 0.377
#   - Deanna Foster (AI Research, Delhi) | Skills: UI/UX Design, Cloud Security, Data Warehousing --> Final Score: 0.366
#   - Shannon Gardner (DevOps, Delhi) | Skills: TensorFlow, NLP, CI/CD --> Final Score: 0.348
#
# Project ID: P369 | Client: Ramirez, Lee and Smith
# Required Skills: NoSQL Database Management, Quantum Computing, Java
# Recommended Employees:
#   - Dr. Michelle Barnes (Cloud Engineering, Mumbai) | Skills: CI/CD, Healthcare Analytics, Edge Computing --> Final Score: 0.39
#   - Amber Navarro (Cloud Engineering, Mumbai) | Skills: DevOps Practices, NoSQL Database Management, Agile Project Management --> Final Score: 0.379
#   - Kathy Bell (Cloud Engineering, Mumbai) | Skills: Terraform, REST APIs, SQL --> Final Score: 0.374
#
# Project ID: P370 | Client: Rogers, Massey and Gutierrez
# Required Skills: Java, Jenkins, CI/CD Pipelines
# Recommended Employees:
#   - Shane Wallace (Cybersecurity, Mumbai) | Skills: Java, Jenkins, CI/CD --> Final Score: 0.429
#   - Eugene Hayes (Cloud Engineering, Mumbai) | Skills: CI/CD Pipelines, AWS, Data Engineering --> Final Score: 0.387
#   - John Stewart (DevOps, Mumbai) | Skills: CI/CD Pipelines, Quantum Computing, Scrum --> Final Score: 0.374
#
# Project ID: P371 | Client: Lee, Adams and May
# Required Skills: Scrum, Real-time Data Processing, Machine Learning
# Recommended Employees:
#   - Cindy Levy (DevOps, Mumbai) | Skills: Real-time Data Processing, Agile Project Management, Microservices --> Final Score: 0.489
#   - John Powell (Data Science, Pune) | Skills: PostgreSQL, Real-time Data Processing, Machine Learning --> Final Score: 0.454
#   - Michelle Robinson (Cloud Engineering, Mumbai) | Skills: Network Security, Data Mesh Architecture, Real-time Data Processing --> Final Score: 0.423
#
# Project ID: P372 | Client: Campbell-Flynn
# Required Skills: Jenkins, NoSQL, Data Warehousing
# Recommended Employees:
#   - Blake Rios (Cybersecurity, Chennai) | Skills: Data Warehousing, API Development, Data Privacy Compliance --> Final Score: 0.365
#   - James Stanley (Cloud Engineering, Pune) | Skills: PostgreSQL, NoSQL, Data Warehousing --> Final Score: 0.347
#   - Elizabeth Boyd (DevOps, Chennai) | Skills: Scrum Methodology, Data Mesh Architecture, Penetration Testing --> Final Score: 0.345
#
# Project ID: P373 | Client: Schultz-Williams
# Required Skills: Kubernetes, Microservices, Scrum
# Recommended Employees:
#   - Lauren Gray (DevOps, Pune) | Skills: GraphQL, Data Lake Implementation, Python --> Final Score: 0.372
#   - Joseph Morales (Cloud Engineering, Pune) | Skills: TensorFlow, Microservices, Scrum Methodology --> Final Score: 0.345
#   - Toni Gonzalez (Full Stack Dev, Pune) | Skills: Terraform, IoT, Quantum Computing --> Final Score: 0.343
#
# Project ID: P374 | Client: Guerrero-Baker
# Required Skills: Agile, React, Machine Learning
# Recommended Employees:
#   - Jennifer Nguyen (Cybersecurity, Chennai) | Skills: .Net, Machine Learning, IoT --> Final Score: 0.375
#   - Jacob Rush (Full Stack Dev, Chennai) | Skills: Business Intelligence, Scrum, Data Quality Management --> Final Score: 0.346
#   - Ann Jordan (Cybersecurity, Chennai) | Skills: UI/UX Design, SQL, Network Security --> Final Score: 0.344
#
# Project ID: P375 | Client: Mejia-Stone
# Required Skills: Edge Computing, Docker, CI/CD Pipelines
# Recommended Employees:
#   - Jessica Sweeney (Cloud Engineering, Pune) | Skills: NoSQL Database Management, Edge Computing, Docker --> Final Score: 0.458
#   - Justin Butler (DevOps, Delhi) | Skills: Docker, CI/CD Pipelines, Edge Computing --> Final Score: 0.426
#   - Misty Yoder (DevOps, Pune) | Skills: CI/CD Pipelines, Microservices, SQL --> Final Score: 0.393
#
# Project ID: P376 | Client: Spencer-King
# Required Skills: DevOps Practices, Scrum Methodology, Cloud Security
# Recommended Employees:
#   - Carrie Evans (DevOps, Chennai) | Skills: Scrum Methodology, Cloud Security, DevOps Practices --> Final Score: 0.417
#   - Robert Obrien Jr. (Cybersecurity, Chennai) | Skills: Agile, Scrum Methodology, Cloud Security --> Final Score: 0.389
#   - Anne Strong (Full Stack Dev, Mumbai) | Skills: Cloud Security, REST APIs, CI/CD --> Final Score: 0.36
#
# Project ID: P377 | Client: Evans PLC
# Required Skills: .Net, Microservices, Serverless Architecture
# Recommended Employees:
#   - Amber Navarro (Cloud Engineering, Mumbai) | Skills: DevOps Practices, NoSQL Database Management, Agile Project Management --> Final Score: 0.353
#   - Robert Mitchell DVM (Cybersecurity, Mumbai) | Skills: API Development, NoSQL Database Management, Jenkins --> Final Score: 0.351
#   - John Dalton (Full Stack Dev, Mumbai) | Skills: Quantum Computing, NLP, Data Privacy Compliance --> Final Score: 0.34
#
# Project ID: P378 | Client: Martinez Group
# Required Skills: Blockchain, Node.js, DevOps Practices
# Recommended Employees:
#   - Alan Drake (Full Stack Dev, Chennai) | Skills: Scrum Methodology, .Net, Quantum Computing --> Final Score: 0.43
#   - Emily Garcia (DevOps, Chennai) | Skills: UI/UX Design, Edge Computing, Node.js --> Final Score: 0.427
#   - Barry Collins (AI Research, Chennai) | Skills: DevOps Practices, Azure, Java --> Final Score: 0.413
#
# Project ID: P379 | Client: Smith Group
# Required Skills: Robotic Process Automation, GraphQL, CI/CD
# Recommended Employees:
#   - Raymond Mendoza (Cloud Engineering, Delhi) | Skills: Data Engineering, Kubernetes, Robotic Process Automation --> Final Score: 0.459
#   - Nicholas Huynh (Full Stack Dev, Delhi) | Skills: PostgreSQL, IoT, Cloud Security --> Final Score: 0.426
#   - Patrick Smith (Data Science, Delhi) | Skills: GraphQL, Robotic Process Automation, TensorFlow --> Final Score: 0.41
#
# Project ID: P380 | Client: Phillips Ltd
# Required Skills: PostgreSQL, NLP, GraphQL
# Recommended Employees:
#   - Kristin Holt (Cybersecurity, Pune) | Skills: Cybersecurity, Cloud Security, PostgreSQL --> Final Score: 0.357
#   - Christopher Allen (Data Science, Pune) | Skills: CI/CD, Data Quality Management, Machine Learning --> Final Score: 0.356
#   - Joel Hamilton (Cybersecurity, Pune) | Skills: Quantum Computing, Incident Response, Business Intelligence --> Final Score: 0.345
#
# Project ID: P381 | Client: Whitehead, Blackburn and Benjamin
# Required Skills: Data Mesh Architecture, NoSQL, GraphQL
# Recommended Employees:
#   - Charlotte West (Data Science, Chennai) | Skills: Data Mesh Architecture, Scrum, Cloud Security --> Final Score: 0.436
#   - Dr. David Bass (DevOps, Chennai) | Skills: GraphQL, Agile Project Management, GraphQL API Development --> Final Score: 0.393
#   - Elizabeth Boyd (DevOps, Chennai) | Skills: Scrum Methodology, Data Mesh Architecture, Penetration Testing --> Final Score: 0.387
#
# Project ID: P382 | Client: Patel, Michael and Hensley
# Required Skills: SQL, UI/UX Design, Data Engineering
# Recommended Employees:
#   - Isaac Johnson (DevOps, Mumbai) | Skills: Scrum Methodology, UI/UX Design, Python --> Final Score: 0.473
#   - Laura Velazquez (Data Science, Mumbai) | Skills: UI/UX Design, Data Governance, SQL Database Management --> Final Score: 0.422
#   - Samantha Moon (Cloud Engineering, Mumbai) | Skills: DevOps Practices, AWS, Container Orchestration --> Final Score: 0.413
#
# Project ID: P383 | Client: Gibson, Sparks and Hutchinson
# Required Skills: API Development, Incident Response, Kubernetes
# Recommended Employees:
#   - Leslie Randolph MD (Cybersecurity, Mumbai) | Skills: SQL Database Management, GraphQL API Development, Data Engineering --> Final Score: 0.396
#   - Erin Flores (Cloud Engineering, Pune) | Skills: Data Lake Implementation, GraphQL API Development, NoSQL Database Management --> Final Score: 0.385
#   - Aaron Wheeler (Cloud Engineering, Pune) | Skills: Incident Response, TensorFlow, Mobile Development --> Final Score: 0.363
#
# Project ID: P384 | Client: Avila PLC
# Required Skills: Python, Agile, Data Engineering
# Recommended Employees:
#   - Casey Graham (Cybersecurity, Pune) | Skills: Python, SQL, Cybersecurity --> Final Score: 0.508
#   - Michael Rodriguez (Cloud Engineering, Pune) | Skills: Agile Project Management, PostgreSQL, UI/UX Design --> Final Score: 0.424
#   - Michael Cole (AI Research, Pune) | Skills: GraphQL, Python, Agile Project Management --> Final Score: 0.41
#
# Project ID: P385 | Client: Wilson and Sons
# Required Skills: Agile Project Management, Penetration Testing, Node.js
# Recommended Employees:
#   - Michael Rodriguez (Cloud Engineering, Pune) | Skills: Agile Project Management, PostgreSQL, UI/UX Design --> Final Score: 0.58
#   - Elizabeth Bennett (Data Science, Pune) | Skills: Terraform, SQL Database Management, Penetration Testing --> Final Score: 0.462
#   - Tracy Peck (DevOps, Pune) | Skills: Agile Project Management, Penetration Testing, Cybersecurity --> Final Score: 0.427
#
# Project ID: P386 | Client: Bush Group
# Required Skills: Microservices Architecture, SQL Database Management, Blockchain
# Recommended Employees:
#   - Brian Davis (DevOps, Chennai) | Skills: Terraform, Kubernetes, Microservices Architecture --> Final Score: 0.377
#   - Curtis Andersen (DevOps, Chennai) | Skills: Blockchain, Microservices Architecture, SQL Database Management --> Final Score: 0.368
#   - William Johnson (Cybersecurity, Chennai) | Skills: PostgreSQL, CI/CD, Data Engineering --> Final Score: 0.367
#
# Project ID: P387 | Client: Martin-Brown
# Required Skills: Azure, Network Security, Mobile Development
# Recommended Employees:
#   - Robert Obrien Jr. (Cybersecurity, Chennai) | Skills: Agile, Scrum Methodology, Cloud Security --> Final Score: 0.396
#   - Tracy Pearson (AI Research, Chennai) | Skills: NLP, Data Quality Management, Network Security --> Final Score: 0.381
#   - William Williams (DevOps, Chennai) | Skills: Blockchain, Mobile Development, Data Visualization --> Final Score: 0.37
#
# Project ID: P388 | Client: Wolf-Jones
# Required Skills: Blockchain, Machine Learning, Edge Computing
# Recommended Employees:
#   - Nichole Dennis (Data Science, Delhi) | Skills: Java, Python, React --> Final Score: 0.448
#   - Juan Castro (Full Stack Dev, Delhi) | Skills: DevOps Practices, UI/UX Design, Agile Project Management --> Final Score: 0.381
#   - Andrew Watson (AI Research, Delhi) | Skills: Network Security, Data Engineering, CI/CD Pipelines --> Final Score: 0.37
#
# Project ID: P389 | Client: Strickland PLC
# Required Skills: Business Intelligence, Data Visualization, Real-time Data Processing
# Recommended Employees:
#   - Julie White (Cybersecurity, Delhi) | Skills: Data Engineering, Agile Project Management, Business Intelligence --> Final Score: 0.466
#   - Shelly Fields (Full Stack Dev, Delhi) | Skills: Real-time Data Processing, Serverless Architecture, NoSQL --> Final Score: 0.446
#   - Megan Davis (Cybersecurity, Delhi) | Skills: Microservices, Data Privacy Compliance, Quantum Computing --> Final Score: 0.424
#
# Project ID: P390 | Client: George Ltd
# Required Skills: React, REST APIs, CI/CD Pipelines
# Recommended Employees:
#   - Travis Smith (DevOps, Delhi) | Skills: REST APIs, CI/CD Pipelines, Data Privacy Compliance --> Final Score: 0.43
#   - Emily Webb (Data Science, Pune) | Skills: PostgreSQL, CI/CD, Data Mesh Architecture --> Final Score: 0.395
#   - Samantha Floyd (DevOps, Pune) | Skills: UI/UX Design, Data Governance, Jenkins --> Final Score: 0.392
#
# Project ID: P391 | Client: Wilson, Miller and Davis
# Required Skills: IoT, Data Quality Management, DevOps Practices
# Recommended Employees:
#   - Michael Stevens DDS (Full Stack Dev, Chennai) | Skills: Data Governance, Scrum Methodology, Blockchain --> Final Score: 0.473
#   - Bryan Preston (Data Science, Chennai) | Skills: Incident Response, Agile Project Management, DevOps Practices --> Final Score: 0.421
#   - Nathan Whitehead (AI Research, Chennai) | Skills: IoT, Data Visualization, GraphQL API Development --> Final Score: 0.394
#
# Project ID: P392 | Client: Holt and Sons
# Required Skills: NoSQL, SQL, Penetration Testing
# Recommended Employees:
#   - Elizabeth Bennett (Data Science, Pune) | Skills: Terraform, SQL Database Management, Penetration Testing --> Final Score: 0.436
#   - Erin Flores (Cloud Engineering, Pune) | Skills: Data Lake Implementation, GraphQL API Development, NoSQL Database Management --> Final Score: 0.427
#   - Michael Rodriguez (Cloud Engineering, Pune) | Skills: Agile Project Management, PostgreSQL, UI/UX Design --> Final Score: 0.363
#
# Project ID: P393 | Client: Jordan-Mayer
# Required Skills: Terraform, Mobile Development, Data Warehousing
# Recommended Employees:
#   - Benjamin Walker (AI Research, Pune) | Skills: NLP, Mobile Development, Data Warehousing --> Final Score: 0.449
#   - Bryan Banks (Cloud Engineering, Pune) | Skills: Data Warehousing, TensorFlow, DevOps Practices --> Final Score: 0.422
#   - Tyler Dominguez (Data Science, Pune) | Skills: Data Mesh Architecture, Data Warehousing, AWS --> Final Score: 0.394
#
# Project ID: P394 | Client: Figueroa, Delgado and Harrell
# Required Skills: Incident Response, Blockchain, PostgreSQL
# Recommended Employees:
#   - Michael Green (Full Stack Dev, Mumbai) | Skills: Incident Response, PostgreSQL, Data Visualization --> Final Score: 0.418
#   - Nicholas Riley (Cloud Engineering, Mumbai) | Skills: NLP, Real-time Data Processing, Incident Response --> Final Score: 0.372
#   - Amber Navarro (Cloud Engineering, Mumbai) | Skills: DevOps Practices, NoSQL Database Management, Agile Project Management --> Final Score: 0.368
#
# Project ID: P395 | Client: Morgan-Fisher
# Required Skills: Cloud Security, API Development, GraphQL
# Recommended Employees:
#   - Joshua Lutz (AI Research, Pune) | Skills: Node.js, Cloud Security, API Development --> Final Score: 0.479
#   - Breanna Miller (Data Science, Delhi) | Skills: CI/CD, GraphQL API Development, GraphQL --> Final Score: 0.458
#   - Daryl Coffey (Cybersecurity, Delhi) | Skills: GraphQL API Development, Microservices, REST APIs --> Final Score: 0.387
#
# Project ID: P396 | Client: Hughes-Garza
# Required Skills: Edge Computing, IoT, Machine Learning
# Recommended Employees:
#   - Samantha Henry (AI Research, Delhi) | Skills: TensorFlow, Scrum, Machine Learning --> Final Score: 0.367
#   - Melanie Martinez (Data Science, Delhi) | Skills: Quantum Computing, Machine Learning, Penetration Testing --> Final Score: 0.352
#   - Dr. Fernando Tapia DVM (DevOps, Delhi) | Skills: DevOps Practices, TensorFlow, Microservices Architecture --> Final Score: 0.351
#
# Project ID: P397 | Client: Harris Ltd
# Required Skills: Business Intelligence, Data Visualization, Quantum Computing
# Recommended Employees:
#   - Kristen Pratt (Data Science, Chennai) | Skills: SQL Database Management, Quantum Computing, GraphQL --> Final Score: 0.421
#   - Jacob Rush (Full Stack Dev, Chennai) | Skills: Business Intelligence, Scrum, Data Quality Management --> Final Score: 0.401
#   - Jacob Wall (Full Stack Dev, Chennai) | Skills: Business Intelligence, PostgreSQL, Data Mesh Architecture --> Final Score: 0.397
#
# Project ID: P398 | Client: Delgado Group
# Required Skills: NoSQL, Container Orchestration, Terraform
# Recommended Employees:
#   - Brandon Everett (DevOps, Delhi) | Skills: Network Security, GraphQL, NoSQL Database Management --> Final Score: 0.369
#   - Christopher Yu (Cybersecurity, Delhi) | Skills: Business Intelligence, TensorFlow, CI/CD --> Final Score: 0.358
#   - Jeffery Horn (Full Stack Dev, Delhi) | Skills: Quantum Computing, Container Orchestration, IoT --> Final Score: 0.357
#
# Project ID: P399 | Client: Aguilar-Francis
# Required Skills: Data Lake Implementation, Container Orchestration, IoT
# Recommended Employees:
#   - Erin Flores (Cloud Engineering, Pune) | Skills: Data Lake Implementation, GraphQL API Development, NoSQL Database Management --> Final Score: 0.377
#   - Elizabeth Waters DDS (Full Stack Dev, Pune) | Skills: Blockchain, Docker, Big Data --> Final Score: 0.369
#   - Julie Vang (Data Science, Pune) | Skills: Data Mesh Architecture, Scrum, CI/CD Pipelines --> Final Score: 0.359
#
# Project ID: P400 | Client: Noble, Wilson and Lee
# Required Skills: GraphQL, Agile Project Management, Real-time Data Processing
# Recommended Employees:
#   - Julie White (Cybersecurity, Delhi) | Skills: Data Engineering, Agile Project Management, Business Intelligence --> Final Score: 0.55
#   - Cindy Levy (DevOps, Mumbai) | Skills: Real-time Data Processing, Agile Project Management, Microservices --> Final Score: 0.497
#   - Karen Robinson (Cybersecurity, Delhi) | Skills: REST APIs, Agile Project Management, Real-time Data Processing --> Final Score: 0.485

# %%
# Out:
# === Evaluation Metrics ===
# Precision@3: 0
# Recall@3: 0

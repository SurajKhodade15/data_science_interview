# %% [markdown]
# # 📌 Basic Intro Statistics & Math Interview Q\&A
#
# ---
#
# ### **Q1. What is the difference between Descriptive and Inferential Statistics?**
#
# **Answer:**
#
# * **Descriptive statistics** → summarize and describe data (mean, median, std, variance).
# * **Inferential statistics** → make predictions or inferences about a population using a sample (hypothesis testing, confidence intervals, regression).
#
# ---
#
# ### **Q2. What is the difference between Population and Sample? Why is sampling important?**
#
# **Answer:**
#
# * **Population** → the entire dataset (e.g., all users of Netflix).
# * **Sample** → a subset of the population (e.g., 1,000 randomly selected Netflix users).
# * Sampling is important because analyzing an entire population is often impractical; the **Central Limit Theorem** ensures that sample means approximate normality.
#
# ---
#
# ### **Q3. Explain Mean, Median, and Mode with an example.**
#
# **Answer:**
# For data: `[2, 4, 4, 6, 8]`
#
# * Mean = (2+4+4+6+8)/5 = 4.8
# * Median = middle value = 4
# * Mode = most frequent value = 4
#
# 👉 Interviewers may ask: *When would you prefer Median over Mean?*
# Answer: When data has **outliers or skewed distribution**.
#
# ---
#
# ### **Q4. What is Variance and Standard Deviation?**
#
# **Answer:**
#
# * **Variance** = average squared deviation from mean.
# * **Standard deviation (SD)** = square root of variance (in same units as data).
#   👉 High variance/SD = data is spread out, low variance/SD = data is tightly clustered.
#
# ---
#
# ### **Q5. What is Probability?**
#
# **Answer:**
# Probability measures the likelihood of an event occurring, ranging from **0 to 1**.
#
# * Example: Tossing a fair coin → P(Heads) = 0.5.
#
# ---
#
# ### **Q6. What is Bayes’ Theorem and why is it important in ML?**
#
# **Answer:**
#
# $$
# P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}
# $$
#
# * It helps update probabilities when new evidence is available.
# * Widely used in **Naïve Bayes classifiers, spam detection, recommendation systems**.
#
# ---
#
# ### **Q7. What are Type I and Type II Errors?**
#
# **Answer:**
#
# * **Type I Error (False Positive):** Rejecting a true null hypothesis.
# * **Type II Error (False Negative):** Failing to reject a false null hypothesis.
#   👉 Example: In medical tests, a **Type I error** = diagnosing disease when patient is healthy; **Type II error** = missing a real disease.
#
# ---
#
# ### **Q8. What is Correlation vs Covariance?**
#
# **Answer:**
#
# * **Covariance** → measures how two variables vary together.
# * **Correlation** → normalized version of covariance, always between **-1 and +1**.
#   👉 Correlation is dimensionless and easier to interpret.
#
# ---
#
# ### **Q9. What is the Central Limit Theorem (CLT)? Why is it important?**
#
# **Answer:**
#
# * CLT states that the **sampling distribution of the sample mean** tends to be **normal**, regardless of population distribution, as sample size increases (n > 30 is a rule of thumb).
# * Importance: Enables us to apply **hypothesis testing, confidence intervals** in ML/AI.
#
# ---
#
# ### **Q10. What is a Probability Distribution? Give examples.**
#
# **Answer:**
#
# * A probability distribution describes how values of a random variable are distributed.
# * Examples:
#
#   * Discrete: Bernoulli, Binomial, Poisson.
#   * Continuous: Normal, Exponential, Uniform.
#     👉 Normal distribution is crucial in ML because many algorithms assume normality.
#
# ---
